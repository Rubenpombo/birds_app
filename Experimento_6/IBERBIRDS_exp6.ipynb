# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
drive.flush_and_unmount()
# Out:
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.7/107.7 GB disk)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bd8e0751dd7e> in <cell line: 0>()
#       2 import ultralytics
#       3 ultralytics.checks()
# ----> 4 drive.flush_and_unmount()
#
# NameError: name 'drive' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# Out:
# Mounted at /content/drive
# /content

# %%
# !unzip '/content/drive/MyDrive/OrniV7.zip'
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: OrniV7/train/images/Neophron_percnopterus/27.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/271.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/272.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/273.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/274.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/275.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/276.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/277.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/278.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/279.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/28.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/280.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/282.png
#   inflating: OrniV7/train/images/Neophron_percnopterus/283.png
# ...

# %% [markdown]
# TRAIN THE MODEL

# %%
# Se continua el entrenamiento del modelo YOLO11l desde el último punto guardado con los parámetros especificados
# !yolo train model=/content/drive/MyDrive/YOLO_Train/train/weights/epoch84.pt data='/content/OrniV7/OrniV7.yaml' epochs=200 imgsz=640 patience=10 optimizer=auto save_period=4 batch=-1 project ='/content/drive/MyDrive/YOLO_Train' resume=True
# Out:
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import os
import time
import shutil
from google.colab import files

ruta_carpeta = "/content/drive/MyDrive/YOLO_Train"
nombre_archivo_salida = "/content/Resultados_Exp6.zip"

# Comprimir la carpeta
shutil.make_archive(nombre_archivo_salida.replace(".zip", ""), 'zip', ruta_carpeta)

# Descargar el archivo ZIP
files.download(nombre_archivo_salida)
